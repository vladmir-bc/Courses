# %%
import numpy
numpy.__version__
# Out:
# '1.19.2'

# %%
import scipy
scipy.__version__
# Out:
# '1.5.2'

# %%
import pandas
pandas.__version__
# Out:
# '1.1.5'

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.3.2'
